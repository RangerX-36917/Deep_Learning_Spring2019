# %% [markdown]
# # Part I

# %% [markdown]
# Test and training dataset

# %%
import sklearn.datasets as skd
import numpy as np
import matplotlib.pyplot as plt
dataSet, labels = skd.make_moons(1000, noise = 0.01)
testDataSet, testLabels = skd.make_moons(200, noise = 0.01)

plt.scatter(dataSet[:, 0], dataSet[:, 1], s = 40, color ={'r'}) 
plt.scatter(testDataSet[:, 0], testDataSet[:, 1], s = 40, color ={'g'}) 
plt.xlabel("X") 
plt.ylabel("Y") 
plt.show() 
plt.clf()

# %%
from mlp_numpy import *
from modules import *
from train_mlp_numpy import *
testResult = []
trainResult = []
DNN_HIDDEN_UNITS_DEFAULT = '20'
LEARNING_RATE_DEFAULT = 1e-1
MAX_EPOCHS_DEFAULT = 1500
EVAL_FREQ_DEFAULT = 20
mlp = MLP(2,[20],2)
mlp.lRate = LEARNING_RATE_DEFAULT
CE = CrossEntropy()
features = {}
n_features = 2
n = 0
labels_onehot = []
for l in labels:
    x = np.zeros(n_features)
    if(l in features):
        x[features[l]] = 1
    else:
        features[l] = n
        x[features[l]] = 1
        n += 1
    labels_onehot.append(x)
for i in range(MAX_EPOCHS_DEFAULT):
    if(i % EVAL_FREQ_DEFAULT == 0):
        correct = 0
        for data, label in zip(testDataSet, testLabels):
            result = mlp.forward(data)
            if(np.argmax(result) == features[label] and result.max() != 0.5):
                correct += 1
        testResult.append(correct*100/len(testDataSet))
        correct = 0
        for data, label in zip(dataSet, labels):
            result = mlp.forward(data)
            if(np.argmax(result) == features[label] and result.max() != 0.5):
                correct += 1
        trainResult.append(correct*100/len(dataSet))
    train(mlp, dataSet, labels_onehot, "SGD")

x = range(0,MAX_EPOCHS_DEFAULT,20)
plt.plot(x, trainResult,label = "training accuracy")
plt.plot(x, testResult, label = "test accuracy")
plt.legend(loc="best")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("SGD Numpy MLP Accuracy")
plt.show()

# %%
from pytorch_mlp import *
from pytorch_train_mlp import *
dataSet = torch.Tensor(dataSet)
labels = torch.Tensor(labels).long()
testDataSet = torch.Tensor(testDataSet)
testLabels = torch.Tensor(testLabels).long()

# %%
DNN_HIDDEN_UNITS_DEFAULT = '20'
LEARNING_RATE_DEFAULT = 1e-1
MAX_EPOCHS_DEFAULT = 150
EVAL_FREQ_DEFAULT = 20

mlp = torchMLP(2, [20], 2)

ep, acs = train(mlp, dataSet, labels, testDataSet, testLabels, MAX_EPOCHS_DEFAULT)
print(ep, acs)
plt.plot(ep, acs)
plt.show()
# Out:
# epoch: 0  ac:  85.5 %
# epoch: 1  ac:  86.5 %
# epoch: 2  ac:  88.0 %
# epoch: 3  ac:  88.5 %
# epoch: 4  ac:  88.5 %
# epoch: 5  ac:  89.0 %
# epoch: 6  ac:  89.0 %
# epoch: 7  ac:  89.0 %
# epoch: 8  ac:  89.0 %
# epoch: 9  ac:  89.0 %
# epoch: 10  ac:  89.5 %
# epoch: 11  ac:  89.5 %
# epoch: 12  ac:  89.5 %
# epoch: 13  ac:  89.5 %
# epoch: 14  ac:  89.5 %
# epoch: 15  ac:  89.5 %
# epoch: 16  ac:  89.5 %
# epoch: 17  ac:  89.5 %
# epoch: 18  ac:  89.5 %
# epoch: 19  ac:  89.5 %
# epoch: 20  ac:  89.5 %
# epoch: 21  ac:  89.5 %
# epoch: 22  ac:  90.0 %
# epoch: 23  ac:  90.0 %
# epoch: 24  ac:  90.0 %
# epoch: 25  ac:  90.0 %
# epoch: 26  ac:  90.5 %
# epoch: 27  ac:  91.0 %
# epoch: 28  ac:  91.0 %
# epoch: 29  ac:  91.0 %
# epoch: 30  ac:  92.0 %
# epoch: 31  ac:  92.5 %
# epoch: 32  ac:  93.0 %
# epoch: 33  ac:  94.0 %
# epoch: 34  ac:  94.0 %
# epoch: 35  ac:  94.5 %
# epoch: 36  ac:  95.0 %
# epoch: 37  ac:  96.0 %
# epoch: 38  ac:  97.0 %
# epoch: 39  ac:  97.0 %
# epoch: 40  ac:  98.5 %
# epoch: 41  ac:  99.0 %
# epoch: 42  ac:  99.5 %
# epoch: 43  ac:  100.0 %
# epoch: 44  ac:  100.0 %
# epoch: 45  ac:  100.0 %
# epoch: 46  ac:  100.0 %
# epoch: 47  ac:  100.0 %
# epoch: 48  ac:  100.0 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-12c818f107af> in <module>
#       7 mlp = torchMLP(2, [20], 2)
#       8
# ----> 9 ep, acs = train(mlp, dataSet, labels, testDataSet, testLabels, MAX_EPOCHS_DEFAULT)
#      10 print(ep, acs)
#      11 plt.plot(ep, acs)
#
# ~/Document/Github/Deep_Learning_SPRING2019/Assignment2/Part1/pytorch_train_mlp.py in train(mlp, dataSet, labels, testDataSet, testLabels, epochs)
#      55         data = dataSet[index]
#      56         label = labels[index]
# ---> 57         optimizer.zero_grad()
#      58         result = mlp.forward(data).view(1, -1)
#      59         label = label.view(1, -1)[0]
#
# /usr/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# /usr/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:
